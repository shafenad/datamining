# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# # **ADULT**

# %%
dfAdult = pd.read_csv("adult.csv")
dfAdult.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18        NaN  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                NaN    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 4              30  United-States  <=50K

# %%
# Menghapus kolom
dfAdult.drop(['workclass','education','marital-status','occupation','relationship','race','native-country'],axis='columns',inplace=True)

# %%
#Mencari Data dan Target
dataAdult = dfAdult.drop('income',axis='columns')
target = dfAdult.income

# %%
dataAdult.head()
# Out:
#    age  fnlwgt  educational-num  gender  capital-gain  capital-loss  \
# 0   25  226802                7    Male             0             0
# 1   38   89814                9    Male             0             0
# 2   28  336951               12    Male             0             0
# 3   44  160323               10    Male          7688             0
# 4   18  103497               10  Female             0             0
#
#    hours-per-week
# 0              40
# 1              50
# 2              40
# 3              40
# 4              30

# %%
target.head()
# Out:
# 0    <=50K
# 1    <=50K
# 2     >50K
# 3     >50K
# 4    <=50K
# Name: income, dtype: object

# %%
# pembuatan variabel dummy ( mengubah variabel kategoris menjadi bentuk yang dapat dimengerti oleh model)
gender = pd.get_dummies(dataAdult.gender)
gender.head()
# Out:
#    Female   Male
# 0   False   True
# 1   False   True
# 2   False   True
# 3   False   True
# 4    True  False

# %%
# mengubah variabel kategoris menjadi bentuk yang dapat dimengerti oleh model analisis data,
# dan kemudian menghapus kolom asli yang tidak lagi diperlukan setelah pengkodean one-hot dilakukan

dataAdult = pd.concat([dataAdult,gender],axis='columns')
dataAdult.drop(['gender','Female'],axis='columns',inplace=True)
dataAdult.head(10)
# Out:
#    age  fnlwgt  educational-num  capital-gain  capital-loss  hours-per-week  \
# 0   25  226802                7             0             0              40
# 1   38   89814                9             0             0              50
# 2   28  336951               12             0             0              40
# 3   44  160323               10          7688             0              40
# 4   18  103497               10             0             0              30
# 5   34  198693                6             0             0              30
# 6   29  227026                9             0             0              40
# 7   63  104626               15          3103             0              32
# 8   24  369667               10             0             0              40
# 9   55  104996                4             0             0              10
#
#     Male
# 0   True
# 1   True
# 2   True
# 3   True
# 4  False
# 5   True
# 6   True
# 7   True
# 8  False
# 9   True

# %%
#Melakukan Training
x_train,x_test,y_train,y_test = train_test_split(dataAdult,target,test_size=0.2, random_state=100)
x_train1,x_test1,y_train1,y_test1 = train_test_split(dataAdult,target,test_size=0.3, random_state=100)
x_train2,x_test2,y_train2,y_test2 = train_test_split(dataAdult,target,test_size=0.4, random_state=100)

#Naive Bayes
model = GaussianNB()


#Mencari Akurasi Data Test 0.2
model.fit(x_train,y_train)
print("Data Test 0.2 dengan Accuracy = {:.2f} \n".format(model.score(x_test,y_test)))

#Mencari Akurasi Data Test 0.3
model.fit(x_train1,y_train1)
print("Data Test 0.3 dengan Accuracy = {:.2f} \n".format(model.score(x_test1,y_test1)))

#Mencari Akurasi Data Test 0.4
model.fit(x_train2,y_train2)
print("Data Test 0.4 dengan Accuracy = {:.2f} \n".format(model.score(x_test2,y_test2)))
# Out:
# Data Test 0.2 dengan Accuracy = 0.80
#
# Data Test 0.3 dengan Accuracy = 0.80
#
# Data Test 0.4 dengan Accuracy = 0.79

# %% [markdown]
# # **KOMBINASI DARI ATRIBUT**

# %%
# Adult (Age , educational-num , hours-per-week , gender )
dataAdult.drop(['fnlwgt','capital-gain','capital-loss'],axis='columns',inplace=True)
dataAdult.head()
# Out:
#    age  educational-num  hours-per-week   Male
# 0   25                7              40   True
# 1   38                9              50   True
# 2   28               12              40   True
# 3   44               10              40   True
# 4   18               10              30  False

# %%
#Melakukan Training
x_train,x_test,y_train,y_test = train_test_split(dataAdult,target,test_size=0.2, random_state=100)
x_train1,x_test1,y_train1,y_test1 = train_test_split(dataAdult,target,test_size=0.3, random_state=100)
x_train2,x_test2,y_train2,y_test2 = train_test_split(dataAdult,target,test_size=0.4, random_state=100)

#Naive Bayes
model = GaussianNB()


#Mencari Akurasi Data Test 0.2
model.fit(x_train,y_train)
print("Data Test 0.2 dengan Accuracy = {:.2f} \n".format(model.score(x_test,y_test)))

#Mencari Akurasi Data Test 0.3
model.fit(x_train1,y_train1)
print("Data Test 0.3 dengan Accuracy = {:.2f} \n".format(model.score(x_test1,y_test1)))

#Mencari Akurasi Data Test 0.4
model.fit(x_train2,y_train2)
print("Data Test 0.4 dengan Accuracy = {:.2f} \n".format(model.score(x_test2,y_test2)))
# Out:
# Data Test 0.2 dengan Accuracy = 0.80
#
# Data Test 0.3 dengan Accuracy = 0.81
#
# Data Test 0.4 dengan Accuracy = 0.81

# %%
# Adult (Age , educational-num , gender )
dataAdult.drop('hours-per-week',axis='columns',inplace=True)
dataAdult.head()
# Out:
#    age  educational-num   Male
# 0   25                7   True
# 1   38                9   True
# 2   28               12   True
# 3   44               10   True
# 4   18               10  False

# %%
#Melakukan Training
x_train,x_test,y_train,y_test = train_test_split(dataAdult,target,test_size=0.2, random_state=100)
x_train1,x_test1,y_train1,y_test1 = train_test_split(dataAdult,target,test_size=0.3, random_state=100)
x_train2,x_test2,y_train2,y_test2 = train_test_split(dataAdult,target,test_size=0.4, random_state=100)

#Naive Bayes
model = GaussianNB()


#Mencari Akurasi Data Test 0.2
model.fit(x_train,y_train)
print("Data Test 0.2 dengan Accuracy = {:.2f} \n".format(model.score(x_test,y_test)))

#Mencari Akurasi Data Test 0.3
model.fit(x_train1,y_train1)
print("Data Test 0.3 dengan Accuracy = {:.2f} \n".format(model.score(x_test1,y_test1)))

#Mencari Akurasi Data Test 0.4
model.fit(x_train2,y_train2)
print("Data Test 0.4 dengan Accuracy = {:.2f} \n".format(model.score(x_test2,y_test2)))
# Out:
# Data Test 0.2 dengan Accuracy = 0.80
#
# Data Test 0.3 dengan Accuracy = 0.80
#
# Data Test 0.4 dengan Accuracy = 0.80

# %% [markdown]
# # **Stars**

# %%
dfstarts = pd.read_csv("Stars.csv")
dfstarts.head()
# Out:
#    Unnamed: 0  Temperature  Luminosity  Radius  Absolutemagnitude Starcategory
# 0           0         3068    0.002400  0.1700              16.12  Brown Dwarf
# 1           1         3042    0.000500  0.1542              16.60  Brown Dwarf
# 2           2         2600    0.000300  0.1020              18.70  Brown Dwarf
# 3           3         2800    0.000200  0.1600              16.65  Brown Dwarf
# 4           4         1939    0.000138  0.1030              20.06  Brown Dwarf

# %%
#Mencari Target
target = dfstarts.Starcategory

# %%
# Menghapus kolom
dfstarts.drop(['Starcategory'],axis='columns',inplace=True)

# %%
dfstarts.head()
# Out:
#    Unnamed: 0  Temperature  Luminosity  Radius  Absolutemagnitude
# 0           0         3068    0.002400  0.1700              16.12
# 1           1         3042    0.000500  0.1542              16.60
# 2           2         2600    0.000300  0.1020              18.70
# 3           3         2800    0.000200  0.1600              16.65
# 4           4         1939    0.000138  0.1030              20.06

# %%
target.head()
# Out:
# 0    Brown Dwarf
# 1    Brown Dwarf
# 2    Brown Dwarf
# 3    Brown Dwarf
# 4    Brown Dwarf
# Name: Starcategory, dtype: object

# %%
#Melakukan Training
x_train,x_test,y_train,y_test = train_test_split(dfstarts,target,test_size=0.2, random_state=100)
x_train1,x_test1,y_train1,y_test1 = train_test_split(dfstarts,target,test_size=0.3, random_state=100)
x_train2,x_test2,y_train2,y_test2 = train_test_split(dfstarts,target,test_size=0.4, random_state=100)

#Naive Bayes
model = GaussianNB()

# %%
#Mencari Akurasi Data Test 0.2
model.fit(x_train,y_train)
print("Data Test 0.2 dengan Accuracy = {:.2f} \n".format(model.score(x_test,y_test)))

#Mencari Akurasi Data Test 0.3
model.fit(x_train1,y_train1)
print("Data Test 0.3 dengan Accuracy = {:.2f} \n".format(model.score(x_test1,y_test1)))

#Mencari Akurasi Data Test 0.4
model.fit(x_train2,y_train2)
print("Data Test 0.4 dengan Accuracy = {:.2f} \n".format(model.score(x_test2,y_test2)))
# Out:
# Data Test 0.2 dengan Accuracy = 0.90
#
# Data Test 0.3 dengan Accuracy = 0.90
#
# Data Test 0.4 dengan Accuracy = 0.91

# %% [markdown]
# # **KOMBINASI DARI ATRIBUT**

# %%
#Stars kombinasi antara ( Temperature, Radius)
dfstarts.drop(['Luminosity','Absolutemagnitude'],axis='columns',inplace=True)

# %%
dfstarts.head()
# Out:
#    Unnamed: 0  Temperature  Radius
# 0           0         3068  0.1700
# 1           1         3042  0.1542
# 2           2         2600  0.1020
# 3           3         2800  0.1600
# 4           4         1939  0.1030

# %%
#Melakukan Training
x_train,x_test,y_train,y_test = train_test_split(dfstarts,target,test_size=0.2, random_state=100)
x_train1,x_test1,y_train1,y_test1 = train_test_split(dfstarts,target,test_size=0.3, random_state=100)
x_train2,x_test2,y_train2,y_test2 = train_test_split(dfstarts,target,test_size=0.4, random_state=100)

#Naive Bayes
model = GaussianNB()


#Mencari Akurasi Data Test 0.2
model.fit(x_train,y_train)
print("Data Test 0.2 dengan Accuracy = {:.2f} \n".format(model.score(x_test,y_test)))

#Mencari Akurasi Data Test 0.3
model.fit(x_train1,y_train1)
print("Data Test 0.3 dengan Accuracy = {:.2f} \n".format(model.score(x_test1,y_test1)))

#Mencari Akurasi Data Test 0.4
model.fit(x_train2,y_train2)
print("Data Test 0.4 dengan Accuracy = {:.2f} \n".format(model.score(x_test2,y_test2)))
# Out:
# Data Test 0.2 dengan Accuracy = 0.96
#
# Data Test 0.3 dengan Accuracy = 0.96
#
# Data Test 0.4 dengan Accuracy = 0.95

# %%
#Stars kombinasi antara ( Luminosity, Absolutemagnitude )
dfstarts.drop(['Temperature','Radius'],axis='columns',inplace=True)

# %%
dfstarts.head()
# Out:
#    Unnamed: 0  Luminosity  Absolutemagnitude
# 0           0    0.002400              16.12
# 1           1    0.000500              16.60
# 2           2    0.000300              18.70
# 3           3    0.000200              16.65
# 4           4    0.000138              20.06

# %%
#Melakukan Training
x_train,x_test,y_train,y_test = train_test_split(dfstarts,target,test_size=0.2, random_state=100)
x_train1,x_test1,y_train1,y_test1 = train_test_split(dfstarts,target,test_size=0.3, random_state=100)
x_train2,x_test2,y_train2,y_test2 = train_test_split(dfstarts,target,test_size=0.4, random_state=100)

#Naive Bayes
model = GaussianNB()


#Mencari Akurasi Data Test 0.2
model.fit(x_train,y_train)
print("Data Test 0.2 dengan Accuracy = {:.2f} \n".format(model.score(x_test,y_test)))

#Mencari Akurasi Data Test 0.3
model.fit(x_train1,y_train1)
print("Data Test 0.3 dengan Accuracy = {:.2f} \n".format(model.score(x_test1,y_test1)))

#Mencari Akurasi Data Test 0.4
model.fit(x_train2,y_train2)
print("Data Test 0.4 dengan Accuracy = {:.2f} \n".format(model.score(x_test2,y_test2)))
# Out:
# Data Test 0.2 dengan Accuracy = 0.62
#
# Data Test 0.3 dengan Accuracy = 0.72
#
# Data Test 0.4 dengan Accuracy = 0.62
